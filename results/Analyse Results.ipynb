# %%
import json
import matplotlib.pyplot as plt
import numpy as np

with open(f"gpt2.json", "r") as file:
  gpt2_results = json.load(file)

with open(f"bert_large_uncased.json", "r") as file:
  bert_large_uncased_results = json.load(file)

with open(f"roberta-large.json", "r") as file:
  roberta_large_results = json.load(file)

# %%
num_tests = len(gpt2_results)
half_num_tests = 0.5 * num_tests

########## GPT-2 ##########

gpt2_drop_out_prob_0_1_average_score = 0
gpt2_drop_out_prob_0_25_average_score = 0
gpt2_learning_rate_3_average_score = 0
gpt2_learning_rate_6_average_score = 0
gpt2_labelling_system_1_average_score = 0
gpt2_labelling_system_2_average_score = 0
gpt2_batch_size_4_average_score = 0
gpt2_batch_size_8_average_score = 0
best_gpt2_score = 0
best_gpt2_score_hyperparameters = None

for result in gpt2_results:
  results = result['results']
  hyperparameters = result['hyperparameters']

  # Find best score
  for epoch_results in results:
    if len(epoch_results) == 15: # If length not 15, it is irrelevant data
      if epoch_results['eval_weighted_normalised_accuracy'] > best_gpt2_score:
        best_gpt2_score = epoch_results['eval_weighted_normalised_accuracy']
        best_gpt2_score_hyperparameters = hyperparameters

  # Compare dropout rates
  if hyperparameters['dropout_prob'] == 0.1:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    gpt2_drop_out_prob_0_1_average_score += best_epoch_result / half_num_tests

  if hyperparameters['dropout_prob'] == 0.25:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    gpt2_drop_out_prob_0_25_average_score += best_epoch_result / half_num_tests

  # Compare learning rates
  if hyperparameters['learning_rate'] == 0.00003:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    gpt2_learning_rate_3_average_score += best_epoch_result / half_num_tests

  if hyperparameters['learning_rate'] == 0.00006:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    gpt2_learning_rate_6_average_score += best_epoch_result / half_num_tests

  # Compare labelling systems
  if hyperparameters['data_labelling_system'] == 1:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    gpt2_labelling_system_1_average_score += best_epoch_result / half_num_tests

  if hyperparameters['data_labelling_system'] == 2:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    gpt2_labelling_system_2_average_score += best_epoch_result / half_num_tests

  # Compare batch sizes
  if hyperparameters['batch_size'] == 4:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    gpt2_batch_size_4_average_score += best_epoch_result / half_num_tests

  if hyperparameters['batch_size'] == 8:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    gpt2_batch_size_8_average_score += best_epoch_result / half_num_tests

########## Bert Large Uncased ##########

bert_drop_out_prob_0_1_average_score = 0
bert_drop_out_prob_0_25_average_score = 0
bert_learning_rate_3_average_score = 0
bert_learning_rate_6_average_score = 0
bert_labelling_system_1_average_score = 0
bert_labelling_system_2_average_score = 0
bert_batch_size_8_average_score = 0
bert_batch_size_16_average_score = 0
best_bert_large_uncased_score = 0
best_bert_large_uncased_score_hyperparameters = None

for result in bert_large_uncased_results:
  results = result['results']
  hyperparameters = result['hyperparameters']

  # Find best score
  for epoch_results in results:
    if len(epoch_results) == 15: # If length not 15, it is irrelevant data
      if epoch_results['eval_weighted_normalised_accuracy'] > best_bert_large_uncased_score:
        best_bert_large_uncased_score = epoch_results['eval_weighted_normalised_accuracy']
        best_bert_large_uncased_score_hyperparameters = hyperparameters

  # Compare dropout rates
  if hyperparameters['dropout_prob'] == 0.1:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    bert_drop_out_prob_0_1_average_score += best_epoch_result / half_num_tests

  if hyperparameters['dropout_prob'] == 0.25:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    bert_drop_out_prob_0_25_average_score += best_epoch_result / half_num_tests

  # Compare learning rates
  if hyperparameters['learning_rate'] == 0.00003:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    bert_learning_rate_3_average_score += best_epoch_result / half_num_tests

  if hyperparameters['learning_rate'] == 0.00006:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    bert_learning_rate_6_average_score += best_epoch_result / half_num_tests

  # Compare labelling systems
  if hyperparameters['data_labelling_system'] == 1:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    bert_labelling_system_1_average_score += best_epoch_result / half_num_tests

  if hyperparameters['data_labelling_system'] == 2:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    bert_labelling_system_2_average_score += best_epoch_result / half_num_tests

  # Compare batch sizes
  if hyperparameters['batch_size'] == 8:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    bert_batch_size_8_average_score += best_epoch_result / half_num_tests

  if hyperparameters['batch_size'] == 16:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    bert_batch_size_16_average_score += best_epoch_result / half_num_tests
    
########## Roberta Large ##########

roberta_drop_out_prob_0_1_average_score = 0
roberta_drop_out_prob_0_25_average_score = 0
roberta_learning_rate_3_average_score = 0
roberta_learning_rate_6_average_score = 0
roberta_labelling_system_1_average_score = 0
roberta_labelling_system_2_average_score = 0
roberta_batch_size_8_average_score = 0
roberta_batch_size_16_average_score = 0
best_roberta_large_score = 0
best_roberta_large_score_hyperparameters = None
roberta_large_recall_of_best = 0
roberta_large_prec_of_best = 0
roberta_large_f1_of_best = 0
roberta_large_accuracy_of_best = 0

for result in roberta_large_results:
  results = result['results']
  hyperparameters = result['hyperparameters']

  # Find best score
  for epoch_results in results:
    if len(epoch_results) == 15: # If length not 15, it is irrelevant data
      if epoch_results['eval_weighted_normalised_accuracy'] > best_roberta_large_score:
        best_roberta_large_score = epoch_results['eval_weighted_normalised_accuracy']
        roberta_large_recall_of_best = epoch_results['eval_recall']
        roberta_large_prec_of_best = epoch_results['eval_precision']
        roberta_large_f1_of_best = epoch_results['eval_f1']
        roberta_large_accuracy_of_best = epoch_results['eval_accuracy']
        best_roberta_large_score_hyperparameters = hyperparameters

  # Compare dropout rates
  if hyperparameters['dropout_prob'] == 0.1:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    roberta_drop_out_prob_0_1_average_score += best_epoch_result / half_num_tests

  if hyperparameters['dropout_prob'] == 0.25:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    roberta_drop_out_prob_0_25_average_score += best_epoch_result / half_num_tests

  # Compare learning rates
  if hyperparameters['learning_rate'] == 0.00003:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    roberta_learning_rate_3_average_score += best_epoch_result / half_num_tests

  if hyperparameters['learning_rate'] == 0.00006:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    roberta_learning_rate_6_average_score += best_epoch_result / half_num_tests

  # Compare labelling systems
  if hyperparameters['data_labelling_system'] == 1:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    roberta_labelling_system_1_average_score += best_epoch_result / half_num_tests

  if hyperparameters['data_labelling_system'] == 2:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    roberta_labelling_system_2_average_score += best_epoch_result / half_num_tests

  # Compare batch sizes
  if hyperparameters['batch_size'] == 8:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']  
    roberta_batch_size_8_average_score += best_epoch_result / half_num_tests

  if hyperparameters['batch_size'] == 16:
    best_epoch_result = 0
    for epoch_results in results:
      if len(epoch_results) == 15: # If length not 15, it is irrelevant data
        if epoch_results['eval_weighted_normalised_accuracy'] > best_epoch_result:
          best_epoch_result = epoch_results['eval_weighted_normalised_accuracy']
    roberta_batch_size_16_average_score += best_epoch_result / half_num_tests

########## Plot Chart Comparing Different Base Model Best Scores ##########

models = ['GPT-2', 'Bert Large Uncased', 'Roberta Large']
scores = [best_gpt2_score, best_bert_large_uncased_score, best_roberta_large_score]

plt.figure(figsize=(10, 6))
bars = plt.bar(models, scores, color=['#1f77b4', '#ff7f0e', '#2ca02c'])

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.005, round(yval, 4), ha='center', va='bottom')

plt.xlabel('Models', fontsize=12)
plt.ylabel('Weighted Normalised Accuracy', fontsize=12)
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.savefig('./charts/best_model_bar_chart.png', dpi=300, bbox_inches='tight')

########## Plot Chart Comparing Dropout Rates ##########

models = ['GPT-2', 'Bert Large Uncased', 'Roberta Large']
gpt2_scores = [gpt2_drop_out_prob_0_1_average_score, gpt2_drop_out_prob_0_25_average_score]
bert_scores = [bert_drop_out_prob_0_1_average_score, bert_drop_out_prob_0_25_average_score]
roberta_scores = [roberta_drop_out_prob_0_1_average_score, roberta_drop_out_prob_0_25_average_score]

scores = [gpt2_scores, bert_scores, roberta_scores]

x = np.arange(len(models))
width = 0.35 

fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, [score[0] for score in scores], width, label='Dropout probability = 0.1', color='#03bafc')
rects2 = ax.bar(x + width/2, [score[1] for score in scores], width, label='Dropout probability = 0.25', color='#0303fc')

ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Weighted Normalised Accuracy', fontsize=12)
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.savefig('./charts/drop_out_prob_chart.png', dpi=300, bbox_inches='tight')

########## Plot Chart Comparing Learning Rates ##########

models = ['GPT-2', 'Bert Large Uncased', 'Roberta Large']
gpt2_scores = [gpt2_learning_rate_3_average_score, gpt2_learning_rate_6_average_score]
bert_scores = [bert_learning_rate_3_average_score, bert_learning_rate_6_average_score]
roberta_scores = [roberta_learning_rate_3_average_score, roberta_learning_rate_6_average_score]

scores = [gpt2_scores, bert_scores, roberta_scores]

x = np.arange(len(models))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, [score[0] for score in scores], width, label='Learning Rate = 0.00003', color='#63f542')
rects2 = ax.bar(x + width/2, [score[1] for score in scores], width, label='Learning Rate = 0.00006', color='#167001')

ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Weighted Normalised Accuracy', fontsize=12)
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.savefig('./charts/learning_rate_chart.png', dpi=300, bbox_inches='tight')

########## Plot Chart Comparing Labelling Systems ##########

models = ['GPT-2', 'Bert Large Uncased', 'Roberta Large']
gpt2_scores = [gpt2_labelling_system_1_average_score, gpt2_labelling_system_2_average_score]
bert_scores = [bert_labelling_system_1_average_score, bert_labelling_system_2_average_score]
roberta_scores = [roberta_labelling_system_1_average_score, roberta_labelling_system_2_average_score]

scores = [gpt2_scores, bert_scores, roberta_scores]

x = np.arange(len(models))
width = 0.35 

fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, [score[0] for score in scores], width, label='Labelling System 1', color='#f2f74d')
rects2 = ax.bar(x + width/2, [score[1] for score in scores], width, label='Labelling System 2', color='#909401')

ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Weighted Normalised Accuracy', fontsize=12)
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.savefig('./charts/labelling_system_chart.png', dpi=300, bbox_inches='tight')

########## Plot Chart Comparing Batch Sizes ##########

models = ['GPT-2', 'Bert Large Uncased', 'Roberta Large']
gpt2_scores = [gpt2_batch_size_4_average_score, gpt2_batch_size_8_average_score]
bert_scores = [bert_batch_size_8_average_score, bert_batch_size_16_average_score]
roberta_scores = [roberta_batch_size_8_average_score, roberta_batch_size_16_average_score]

x = np.arange(len(models))
width = 0.35
spacing = width / 2

fig, ax = plt.subplots(figsize=(10, 6))

bar1 = ax.bar(x[0] - spacing, gpt2_scores[0], width=width, label='Batch Size = 4', color='#dbdbdb')
bar2 = ax.bar(x[0] + spacing, gpt2_scores[1], width=width, label='Batch Size = 8', color='#888888')

bar3 = ax.bar(x[1] - spacing, bert_scores[0], width=width, color='#888888')
bar4 = ax.bar(x[1] + spacing, bert_scores[1], width=width, label='Batch Size = 16', color='#2e2e2e')

bar5 = ax.bar(x[2] - spacing, roberta_scores[0], width=width, color='#888888')
bar6 = ax.bar(x[2] + spacing, roberta_scores[1], width=width, color='#2e2e2e')

ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Weighted Normalised Accuracy', fontsize=12)
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

rects = ax.patches
autolabel(rects)

plt.savefig('./charts/batch_size_chart.png', dpi=300, bbox_inches='tight')

########## Plot Chart of Best Model ##########

models = ['Weighted Normalised Accuracy', 'Accuracy', 'Recall', 'Precision', 'F1']
scores = [best_roberta_large_score, roberta_large_accuracy_of_best, roberta_large_recall_of_best, roberta_large_prec_of_best, roberta_large_f1_of_best]

plt.figure(figsize=(10, 6))
bars = plt.bar(models, scores, color=['#2ca02c', '#1f77b4', '#ff7f0e', '#d62728', '#9467bd'], width=0.4)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.005, round(yval, 4), ha='center', va='bottom')

plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.savefig('./charts/best_model_results.png', dpi=300, bbox_inches='tight')

########## Vary Amount of Training Data for Roberta Large With Optimal Hyperparameters ##########

best_results = [0.073955, 0.479592, 0.568783, 0.791752]
training_data_used = [11, 22, 34, 45]

plt.figure(figsize=(10, 6))
bars = plt.bar(training_data_used, best_results, color='#1f77b4', width=8)  # Increase the width of the bars

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.005, round(yval, 4), ha='center', va='bottom')

plt.xlabel('Number Training Examples', fontsize=12)
plt.ylabel('Weighted Normalised Accuracy', fontsize=12)
plt.ylim(0, 1)

plt.xticks(training_data_used)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()  # Adjust layout to prevent overlapping

plt.savefig('./charts/increasing_training_examples.png', dpi=300, bbox_inches='tight')
